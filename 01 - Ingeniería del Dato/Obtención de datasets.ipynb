# %% [markdown]
# # Obtención de los *datasets*

# %% [markdown]
# ## Importaciones

# %%
# sqlite3
import sqlite3
# polars
import pandas as pd
# listdir (os)
from os import listdir

# %% [markdown]
# ## PIB

# %% [markdown]
# ### Obtención de datos

# %%
# Obtener DataFrame desde CSV descargado localmente
df=pd.read_csv("..\\datasets\\PIB per capita (dólares).csv")
# Previsualizar datos
df.head()
# Out:
#        country 1960 1961 1962 1963 1964 1965 1966 1967 1968  ...   2011  \
# 0        Aruba  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  26.6k
# 1  Afghanistan  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    512
# 2       Angola  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   3980
# 3      Albania  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...   3680
# 4      Andorra  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    35k
#
#     2012   2013   2014   2015   2016   2017   2018  2019   2020
# 0  26.2k  27.1k    27k  28.4k  28.8k  29.3k    NaN   NaN    NaN
# 1    558    569    565    556    553    553    547   555    530
# 2   4170   4220   4270   4170   3920   3790   3600  3460   3170
# 3   3740   3780   3860   3950   4090   4250   4430  4540   4390
# 4  33.8k  33.2k  34.7k  35.8k  37.4k  37.7k  38.3k   39k  34.3k
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Base de datos

# %%
# Conectar a la base de datos creando un archivo DB
conn=sqlite3.connect("..\\datasets\\Base de datos TFG.db")
# Almacenar DataFrame
df.to_sql("PIB",conn,index=False)
# Guardar cambios en la base de datos
conn.commit()

# %% [markdown]
# ## Bolsa china

# %% [markdown]
# ### Obtención de datos

# %%
# Clonar repositorio "Multivariate_Stock_Time_Series_Dataset" de "shaocongWu"
# !git clone https://github.com/shaocongWu/Multivariate_Stock_Time_Series_Dataset.git
# Out:
# Cloning into 'Multivariate_Stock_Time_Series_Dataset'...

# %%
# Crear el DataFrame con todos los datos por concatenación (pd.concat)
df=pd.concat(
    # Lista de DataFrames
    [
        # DataFrame con los datos del fichero CSV
        pd.read_csv(
            f"Multivariate_Stock_Time_Series_Dataset\\CSV\\{fichero}", # Ruta del fichero
            index_col=0 # La primera columna del fichero se usará como índice
        )
        # Bucle for comprimido
        for fichero in listdir("Multivariate_Stock_Time_Series_Dataset\\CSV")
    ],
    ignore_index=True # La columna de índices se rehará para el DataFrame concatenado
)
# Mostrar la información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403154 entries, 0 to 403153
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ts_code     403154 non-null  object
#  1   trade_date  403154 non-null  object
#  2   open        403154 non-null  float64
#  3   high        403154 non-null  float64
#  4   low         403154 non-null  float64
#  5   close       403154 non-null  float64
#  6   pre_close   403154 non-null  float64
#  7   change      403154 non-null  float64
#  8   pct_chg     403154 non-null  float64
#  9   vol         403154 non-null  float64
#  10  amount      403154 non-null  float64
#  11  stockcode   0 non-null       object
# dtypes: float64(9), object(3)
# memory usage: 36.9+ MB

# %%
# Eliminar repositorio clonado
# !rmdir /s /q Multivariate_Stock_Time_Series_Dataset

# %% [markdown]
# ### Base de datos

# %%
# Almacenar DataFrame en una tabla llamada "ACCIONES"
df.to_sql("ACCIONES",conn,index=False)
# Guardar los cambios hechos en la base de datos
conn.commit()
# Interrumpir la conexión con la base de datos
conn.close()
